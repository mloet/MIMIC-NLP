# %%
import pandas as pd
import spacy
from spacy import displacy
import scispacy
import medspacy
from medspacy.ner import TargetRule
import en_core_sci_sm
import en_ner_bc5cdr_md

# %%
note_path = '../MIMIC/physionet.org/files/mimiciii/1.4/NOTEEVENTS.csv'
diag_path = '../MIMIC/physionet.org/files/mimiciii/1.4/DIAGNOSES_ICD.csv'

# %%
notes_df = pd.read_csv(note_path)
diag_df = pd.read_csv(diag_path)

# %%
summary_df = notes_df.loc[notes_df['CATEGORY'] == 'Discharge summary', ['SUBJECT_ID', 'HADM_ID', 'TEXT']]
disease_df = diag_df[diag_df['ICD9_CODE'].notna() & diag_df['ICD9_CODE'].str.startswith(('303'))].copy()
patients_df = pd.merge(summary_df, disease_df, on=['SUBJECT_ID', 'HADM_ID'] )

# %%
nlp = spacy.load('en_core_web_sm')
for index, row in patients_df.head(1).iterrows():
  entities = nlp(row['TEXT'])
  displacy.render(entities, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Admission Date:  [**
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2157-4-9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **]              Discharge Date:   [**
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2157-4-18
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **]<br><br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Date of Birth:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# [**
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2106-1-4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# **]             Sex:   M<br><br>Service: MEDICINE<br><br>Allergies:<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Penicillins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br><br>Attending:[**First Name3 (LF)
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# **]<br>Chief Complaint:<br>vomiting blood clots<br><br>Major Surgical or Invasive Procedure:<br>none<br><br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     History of Present Illness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# :<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  yo M with h/o
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  abuse and HTN who presents with emesis<br>with blood clots. Pt states he was vomiting for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24 hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  before<br>coming to the ED. States he last consumed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PTA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and<br>that he drank
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about a fifth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of wine x
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . States he was sleeping<br>at the [**Hospital3
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     328
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# **] and vomited again with red clots. Denies CP,<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SOB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , palpitations,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F/C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , nausea, BRBPR. No black stools,<br>constipation, or diarrhea. No dysuria.<br><br>Past Medical History:<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  abuse<br>HTN<br>?pna with empyema?<br><br>Social History:<br>Pt is homeless. Denies
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IVDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Smokes
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  packs a day.<br><br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Family History
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# :<br>deferred<br><br>Physical Exam:<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  140/92
# <mark class="entity" style="background: #e4e7

# %%
nlp = spacy.load('en_core_sci_sm')
for index, row in patients_df.head(1).iterrows():
  entities = nlp(row['TEXT'])
  displacy.render(entities, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Admission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  Date:  [**2157-4-9**]              Discharge Date:   [**2157-4-18**]<br><br>Date of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Birth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :  [**2106-1-4**]
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sex
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :   M<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MEDICINE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# <br><br>Allergies:<br>Penicillins<br><br>Attending:[**First
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Name3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ) 30**]<br>Chief Complaint:<br>vomiting blood clots<br><br>Major
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Surgical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Invasive Procedure
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :<br>none<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     History
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of Present
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# :<br>50
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yo M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     h/o EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abuse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  who presents with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emesis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# <br>with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     blood clots
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     states
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  he was vomiting for 24 hours before<br>coming to the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ED
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  he last consumed
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  2
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PTA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and<br>that he drank about a fifth of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wine x 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align:

# %%
nlp = medspacy.load()
target_matcher = nlp.get_pipe("medspacy_target_matcher")
target_rules = [
  TargetRule('EtOH abuse', 'DISEASE'),
  TargetRule('EtOH', 'SUBSTANCE'),
  TargetRule('Alcohol Withdrawl', 'PROBLEM'),
  TargetRule('EtOH Withdrawl', 'PROBLEM')
]
target_matcher.add(target_rules)
for index, row in patients_df.head(1).iterrows():
  entities = nlp(row['TEXT'])
  displacy.render(entities, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Admission Date:  [**2157-4-9**]              Discharge Date:   [**2157-4-18**]<br><br>Date of Birth:  [**2106-1-4**]             Sex:   M<br><br>Service: MEDICINE<br><br>Allergies:<br>Penicillins<br><br>Attending:[**First Name3 (LF) 30**]<br>Chief Complaint:<br>vomiting blood clots<br><br>Major Surgical or Invasive Procedure:<br>none<br><br>History of Present Illness:<br>50 yo M with h/o
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH abuse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and HTN who presents with emesis<br>with blood clots. Pt states he was vomiting for 24 hours before<br>coming to the ED. States he last consumed
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SUBSTANCE</span>
# </mark>
#  2 days PTA and<br>that he drank about a fifth of wine x 2. States he was sleeping<br>at the [**Hospital3 328**] and vomited again with red clots. Denies CP,<br>SOB, palpitations, F/C, nausea, BRBPR. No black stools,<br>constipation, or diarrhea. No dysuria.<br><br>Past Medical History:<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH abuse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# <br>HTN<br>?pna with empyema?<br><br>Social History:<br>Pt is homeless. Denies IVDA. Smokes 2 packs a day.<br><br>Family History:<br>deferred<br><br>Physical Exam:<br>97 140/92 93 18 97% RA<br>Gen: in nad. thin, weak, ill-appearing<br>HEENT: MMM, poor dentition. NCAT. injected sclera.<br>CV: RRR, no m/r/g<br>Pulm: CTAB, +R thoracotomy scar<br>Abd: s/nt/nd, +bs.<br>Rectal: guiac beg brown stool.<br>Ext: no c/c/e.<br>Skin: dry<br>Neuro: Slightly tremulous.  A&amp;O X 3.  No flap.  Nonfocal.<br><br>Brief Hospital Course:<br>A/P: 50 yo hispanic M with h/o HTN,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH abuse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  a/w emesis with<br>blood clots.<br>.<br>## GI bleed: Pt's hematocrit has been stable while in house and<br>no further evidence of GI bleeding.  Etiology could have been<br>small [**Doctor First Name 329**] [**Doctor Last Name **] tear vs gastritis.  Pt has no evidence of<br>cirrhosis by physical exam or labs.  He was maintained on IV PPI<br>twice a day and denied any further GI sx's.  He will be<br>discharged on once a day oral protonix.  Scope was initially<br>deferred because of increased risk [**2-16**] his DT's.  He was<br>scheduled for scope on the day of discharge but refused.<br>.<br>##
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SUBSTANCE</span>
# </mark>
#  withdrawal: pt states has had DT's in past.  Initially<br>placed in ICU for closer monitoring, where he required large<br>doses of benzodiazapines for withdrawl (hundreds of milligrams<br>of valium).  He was also started on scheduled haldol, which he<br>should continue as an outpt.  Psych was consulted who agreed<br>with this plan.  Thiamine and folate were continued.  He left<br>the ICU [**4-14**] and tried to leave the hospital twice, each time<br>requiring Code Purple to be initiated (psych emergency) where he<br>needed to transiently be restrained to avoid self injury.  By<br>the time of discharge, the pt was no longer withdrawing and not<br>delerious.<br>.<br>## ARF: BUN/Cr ratio indicate likely prerenal. Elevated bicarb<br>likely [**2-16**] vomiting. Anion gap likely [**2-16**] ARF as well as<br>starvation ketosis.  Renal failure and those associated<br>abnormalities improved with IVF's and nutritional support.  His<br>K and Mg were aggressively repleted.<br>.<br>## Elevated pancreatic enzymes: Lipase/Amylase &gt;2:1 likely<br>affected by
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EtOH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SUBSTANCE</span>
# </mark>
# , however not elevated to a degree sufficient<br>enough to call true pancreatitis. Likely elevated [**2-16**] vomiting.<br>Resolved with no sequelae.<br>.<br>##HTN: unclear of pt's outpt regimen: started prn hydral for SBP<br>&gt;160.  His htn was attributed to the unopposed sympathetic tone<br>of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alcohol withdrawl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# .<br><br>Medications on Admission:<br>unknown<br><br>Discharge Disposition:<br>Home<br><br>Discharge Diagnosis:<br>Hematemesis<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alcohol Withdrawl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# <br><br><br>Discharge Condition:<br>Stable<br><br>Discharge Instructions:<br>If you have these symptoms, call your doctor or go to the ER:<br><br>- vomiting blood<br>- blood in stool<br>- dizziness/visual change<br>- fever/chills<br>- chest pain/cough<br><br>Take all your meds.<br><br>Stop drinking alcohol.<br><br>Followup Instructions:<br>Please call your PCP and see him within 2 weeks<br><br><br><br>Completed by:[**2157-4-18**]</div></span>

# %%
pd.options.mode.chained_assignment = None
import re
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def tsne_plot(model,words,sample_size, preTrained=False):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in words[:sample_size]:
      if preTrained:
          tokens.append(model[word])
      else:
          tokens.append(model.wv[word])
      labels.append(word)

    tokens = np.array(tokens)
    tsne_model = TSNE(perplexity=20, early_exaggeration=12, n_components=2, init='pca', n_iter=1000, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])

    plt.figure(figsize=(16, 16))
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
import spacy
nlp = spacy.load('en_core_sci_sm')
df = notes_df.loc[:100, 'TEXT'].tolist()
corpus = []
for row in range(0, len(df)):
  str_tokens=[]
  tokens=nlp(df[row]).ents
  for i in range(0, len(tokens)):
    str_tokens.append(tokens[i].text)
  corpus.append(str_tokens)

print(corpus)
# Out:
# [['Admission', 'Discharge', 'ADDENDUM', 'RADIOLOGIC', 'STUDIES', 'Radiologic studies', 'cavitary', 'lesions', 'left lung apex', 'consistent with', 'infectious process/tuberculosis', 'moderate-sized left pleural effusion', 'HEAD', 'CT', 'intracranial hemorrhage', 'mass\neffect', 'infarction', 'consistent with', 'ABDOMINAL', 'CT', 'Abdominal CT', 'lesions', 'T10', 'sacrum', 'osteoporosis', 'repeat imaging', 'outpatient', 'M.D.', 'By:[**Hospital', 'MEDQUIST36', 'JOB'], ['Admission', 'Discharge', 'Birth', 'Sex', 'Service', 'MICU', 'female', 'history of emphysema', 'home O2', 'days', 'shortness', 'breath', 'COPD', 'flare', 'days', 'admission', 'taper', 'day', 'oxygen', 'oxygen saturation', 'levofloxacin', 'nebulizers', '[**Hospital1 18**] Emergency Room', '[**Hospital3 **] Emergency Room', 'oxygen saturation', 'CPAP', 'nebulizer', 'treatment', 'Solu-Medrol', 'Review of', 'systems', 'negative', 'Fevers', 'nausea', 'vomiting', 'night sweats', 'weight', 'neurologic changes', 'rashes', 'palpitations', 'orthopnea', 'positive', 'shortness', 'breath', 'exertion', 'shortness of', 'breath', 'nebulizer', 'treatment', 'PAST MEDICAL HISTORY', 'COPD', 'pulmonary function tests', '[**2117', 'FVC', 'predicted', 'FEV1', 'predicted', 'MMF', 'predicted', 'FEV1:FVC ratio', 'predicted', 'improve', 'bronchodilator', 'treatment', 'FVC', 'improve', 'consistent with', 'restrictive\nventilatory defect', 'patient', 'home\noxygen', 'episode', 'steroid', 'taper', 'Lacunar CVA', 'MRI', 'head', 'mild', 'degree', 'multiple', 'T2', 'signal', 'white matter', 'cerebral hemispheres', 'pons', 'region', 'midline', 'abnormalities', 'nonspecific', 'etiology', 'chronic\nmicrovascular infarction', 'lesion', 'shift', 'midline strictures', 'hydrocephalus', 'vascular flow', 'moderate', 'moderate', 'bilateral', 'ethmoid', 'mild left\nmaxillary', 'minimal', 'right sphenoid', 'frontal sinus mucosal\nthickening', 'abnormalities', 'allergic\n', 'inflammatory process', 'enlarged', 'subtotally empty', 'sella', 'Angina', 'stress test', 'minutes', 'rate pressure product', 'maximum', 'heart rate', 'evidence', 'ischemic', 'EKG', 'changes', 'symptoms', 'imaging portion', 'study', 'evidence', 'myocardial ischemia', 'ejection fraction', 'patient denies', 'rest', 'gets angina', 'walking', 'blocks', 'sublingual nitroglycerin', 'Hypothyroidism', 'Synthroid', 'Depression', 'Lexapro', 'Motor vehicle accident', 'head injury', 'years', 'MEDICATIONS', 'ADMISSION', 'Levofloxacin', 'Synthroid', 'Pulmicort nebulizer', 'Albuterol nebulizer', 'Lexapro', 'Protonix', 'Aspirin', 'ALLERGIES', 'Norvasc', 'lightheadedness', 'headache', 'FAMILY HISTORY', 'Noncontributory', 'SOCIAL HISTORY', 'husband', 'Dr. [**Known lastname 1809**', 'eminent', 'Pediatric', 'patient', 'smoker', 'years', 'alcohol use', 'code', 'PHYSICAL EXAM AT TIME', 'ADMISSION', 'Blood pressure', 'regular', 'respirations', 'axillary temperature', 'saturating', 'CPAP', 'dry mucous membranes', 'elderly', 'female', 'Pupils', 'round', 'reactive', 'accommodation', 'Extraocular movements', 'intact', 'Oropharynx\n', 'assess', 'CPAP', 'machine', 'evidence', 'venous pressure', 'strap', 'CPAP', 'obscures', 'exam', 'Cranial nerves II', 'XII', 'intact', 'supple', 'Tachycardic', 'regular', 'obscured', 'loud', 'bilateral', 'wheezing', 'increase', 'expiratory\nphase', 'scattered', 'lung', 'Positive bowel sounds', 'soft', 'nontender', 'nondistended', 'obese', 'no masses', 'Mild edema', 'clubbing', 'cyanosis', 'no rashes', 'right hand hematoma', 'assessed', '[**5', '9**', '9**', 'upper extremities', 'cognition', 'LABORATORY STUDIES', 'White count', 'hematocrit', 'platelets', 'Chem-7', 'Troponin', 'negative', 'CKs', 'negative', 'blood gas', 'pH', 'pO2', 'pCO2', 'Chest x-ray', 'moderate', 'sized', 'hiatal hernia', 'left lower lobe infiltrate', 'segmental atelectasis', 'EKG', 'sinus rhythm', 'beats', 'minute', 'evidence', 'ST-T wave', 'HOSPITAL COURSE', 'COPD/dyspnea/pneumonia', 'patient', 'aggressive', 'steroid', 'taper', 'admitted', 'Medical\nIntensive Care U ...

# %%
model = Word2Vec(corpus, min_count=1)
vocabs = model.wv.key_to_index.keys()
print(vocabs)
print(model.wv['patient'])
# Out:
# dict_keys(['patient', 'day', 'Tablet Sig', 'Tablet', 'PO', 'Daily', 'days', 'Tablet PO', 'admission', 'Admission', 'Patient', 'hours', 'stable', 'daily', 'BLOOD', 'negative', 'BID', 'discharge', 'Pt', 'evidence', 'ED', "patient's", 'mouth', 'baseline', 'HCO3', 'weeks', 'pain', 'breath', 'LF', 'increased', 'admitted', 'history', 'INR', 'TID', 'Delayed Release', 'Please', 'bilaterally', 'MD', 'COPD', 'changes', 'Medications', 'consistent with', 'CXR', 'BP', 'Capsule Sig', 'intact', 'medications', 'CT', 'Service', 'Social History', 'PCP', 'Birth', 'Illness', 'Sex', 'floor', 'Name3', 'Surgical', 'Invasive Procedure', 'week', 'Family History', 'Location', 'time', 'severe', 'HTN', 'Discharge Medications', 'Physical Exam', 'Followup Instructions', 'decreased', 'Capsule PO', 'O2', 'Inhalation', 'hypotension', 'shortness', 'Tablet PO DAILY', 'DAILY', 'Tablet PO DAILY\n', 'DISCHARGE', 'appointment', 'post', 'ICU', 'nausea', 'Coumadin', 'improved', 'symptoms', 'Brief Hospital Course', 'chest pain', 'moderate', 'discontinued', 'NI', 'treated with', 'started', 'Q6H', 'CO2', 'HR', 'dose', 'HEENT', 'MICU', 'elevated', 'follow up', 'course', 'Facility', 'antibiotics', 'MEDICINE', 'home', 'fever', 'outpatient', 'transferred', 'thickened', 'pneumonia', 'denies', 'soft', 'pCO2', 'placement', 'MEDICATIONS', 'fluid', 'RR', 'PRN', 'follow-up', 'male', 'hospitalization', 'Capsule', 'Discharge Disposition', 'pO2', 'CHF', 'constipation', 'blood pressure', 'coumadin', 'aspirin', 'units', 'exam', 'bilateral', 'EKG', 'Aspirin', 'Hypertension', 'hospital', 'worsening', 'years', 'Name8', 'afebrile', 'HCl', 'lesion', 'morning', 'mental status', 'shortness of', 'chest', 'URINE', 'extubated', 'IV', 'improvement', 'evaluation', 'Diagnosis', 'CCU', 'creatinine', 'normal', 'SOB', 'History', 'sent', 'Building', 'CAD', 'vomiting', 'EF', 'Discharge Condition', 'morphine', 'fevers', 'positive', 'RA', 'prescribed', 'died', 'Bactrim', 'hypertension', 'PT', 'Discharge Diagnosis', 'blood', 'diarrhea', 'anemia', 'HS', '[**5', 'Status', 'increasing', 'CTA', 'PM', 'Q4H', 'Lungs', 'PLT', 'Tablet(s', 'liters', 'treated', 'HD', 'abdominal pain', 'IMPRESSION', 'Tablets', 'Pertinent', 'NAD', 'Parking', 'Abdomen', 'Anemia', 'Campus', 'metoprolol', 'abdomen', 'months', 'ERCP', 'Disp:*30', 'TOTAL', 'rehab', 'Medical History', 'pericardial effusion', 'evaluated', 'size', 'female', 'unchanged', 'WBC', 'Solution', 'Lasix', 'Alert', 'Atrial fibrillation', 'DVT', 'chills', 'heart rate', 'episodes', 'treatment', 'Pantoprazole', 'month', 'atrial fibrillation', 'intubation', 'doctor', 'taper', 'Delayed Release(E.C.', 'calHCO3', 'QD', 'postoperative', 'findings', 'discharged', 'RRR', 'colonoscopy', 'status', 'Neuro', 'arrival', 'dialysis', 'vancomycin', 'monitoring', 'hematocrit', 'PE', 'rhythm', 'reports', 'level', 'Stable', 'extremities', 'ECHO', 'MRI', 'LVEF>55', 'medication', 'Release', 'wheezing', 'ST', 'infection', 'alert', 'JVP', 'regular', 'management', 'HIV', 'Sig', 'EAST     ', '[**4', 'respiratory distress', 'Mental Status', 'Drugs', 'SBP', 'dyspnea', '14**', 'Denies', 'temperature', 'left atrium', 'woman', 'LAD', 'anticoagulation', 'Solution Sig', 'ADMISSION', 'episode', 'drainage', 'MMM', 'M.D.', 'consulted', 'tenderness', '[**2', 'JOB', 'MEDQUIST36', 'supple', 'resolved', 'lungs', 'PAST MEDICAL HISTORY', 'Levofloxacin', 'pleural effusions', 'bleeding', 'hematoma', 'ALLERGIES', 'presentation', 'regimen', 'PERRL', 'NamePattern2', 'rate', 'Labs', 'Metoprolol', 'surgery', 'mg/5', 'MI', 'PNA', 'exacerbation', 'Level', 'NameIs', 'Dr. [**Last Name (STitle) **', 'GERD', 'evaluate', 'heparin', 'lasix', 'admitted with', 'levofloxacin', 'PTT', 'minutes', 'oriented', 'minimal', 'EGD', 'year', 'night', 'SC', 'EOMI', 'POD', 'Consciousness', 'congestive heart failure', 'Discharge Instructions', 'man', 'Type-ART', 'acute distress', 'BS', 'ASA', 'HOSPITAL COURSE', 'oxygen saturation', 'ANION', 'Atorvastatin', 'sinus rhythm', 'right', 'condition', 'drop', 'mild', 'catheterization', 'hypotensiv ...
# [-0.03585071  0.14836381  0.05985603 -0.01905053 -0.08797344 -0.17141306
#   0.05480721  0.2518029  -0.08222692 -0.06586971 -0.02847384 -0.18866234
#  -0.02817655  0.07279065 -0.01450198 -0.08492692  0.07310964 -0.20484167
#   0.03260867 -0.25036815  0.07265797  0.08513913  0.05396478 -0.11638743
#  -0.00504307 -0.05004155 -0.07392816 -0.05212637 -0.0455092  -0.02237897
#   0.11487905  0.02882296  0.09104685 -0.03614476 -0.0291861   0.02814857
#   0.00541889 -0.14278947 -0.07988734 -0.21657148 -0.02774123 -0.06557962
#  -0.00413696 -0.02395772  0.06468208 -0.0308547  -0.13873303  0.04142686
#   0.04965124  0.13316107  0.03522371 -0.05375968 -0.07418229  0.01599308
#  -0.05481648  0.02025515  0.12674204  0.03015037 -0.12241957  0.10932774
#   0.02516208  0.07035615 -0.05597879 -0.00756573 -0.15642925  0.04101994
#   0.06444122  0.06898466 -0.1378885   0.10811488 -0.12969257  0.0580822
#   0.07486393 -0.08506273  0.14416814  0.04436776  0.05887888 -0.00409076
#  -0.13438931  0.06524289 -0.05050252  0.06869702 -0.06868182  0.18904692
#   0.00855545  0.01359156 -0.05692331  0.15388314  0.07342632  0.08932513
#   0.15070722  0.07653502  0.01341252  0.06175765  0.21864788  0.08777452
#   0.05474656 -0.09779076  0.05967461  0.07549028]

# %%
new_v = np.array(list(vocabs))
tsne_plot(model, new_v, -1)
